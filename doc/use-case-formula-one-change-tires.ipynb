# %% [markdown]
# # Use case: formula one pitstop
#
# This example is based on the DailyMail blog entry https://www.dailymail.co.uk/sport/formulaone/article-4401632/Formula-One-pit-stop-does-crew-work.html where a nice image shows 21 people changing the 4 tires of a Formula 1 Ferrari. In this example, only 16 out 21 people are represented. This notebook can be tested online at mybinder.org
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/tpaviot/ProcessScheduler/HEAD?filepath=doc/use-case-formula-one-change-tires.ipynb)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("aHSUp7msCIE", width=800, height=300)

# %% [markdown]
# ### Imports

# %%
import processscheduler as ps

# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ### Create the scheduling problem
# The total horizon is not knwown, leave it empty and only set the problem name.

# %%
change_tires_problem = ps.SchedulingProblem(name="ChangeTires")

# %% [markdown]
# ### Create the 16 available resources
# Each people in and around the car is represented as a worker.

# %%
nb_lifters = 2
nb_gunners = 4
nb_tyre_handlers = 8
nb_stabilizers = 2

# %%
# Lift tasks
lifters = [ps.Worker(name="JackOperator%i" % (i + 1)) for i in range(nb_lifters)]
gunners = [ps.Worker(name="Gunner%i" % (i + 1)) for i in range(nb_gunners)]
tyre_handlers = [ps.Worker(name="Handler%i" % (i + 1)) for i in range(nb_tyre_handlers)]
stabilizers = [ps.Worker(name="Stabilizer%i" % (i + 1)) for i in range(nb_stabilizers)]

# %% [markdown]
# ### Create tasks and assign resources
# One period is mapped to one second. For example, if lifting the rear take 2sec then the duration will be set to 2.

# %%
# lift tasks and lifters
# both lift tasks can be processed by any one of the lifters
lift_rear_up = ps.FixedDurationTask(name="LiftRearUp", duration=2)
lift_front_up = ps.FixedDurationTask(name="LiftFrontUp", duration=2)
lift_rear_up.add_required_resource(lifters[0])
lift_front_up.add_required_resource(lifters[1])

lift_rear_down = ps.FixedDurationTask(name="LiftRearDown", duration=2)
lift_front_down = ps.FixedDurationTask(name="LiftFrontDown", duration=2)
lift_rear_down.add_required_resource(lifters[0])
lift_front_down.add_required_resource(lifters[1])

# unscrew tasks
unscrew_front_left_tyre = ps.FixedDurationTask(name="UnScrewFrontLeftTyre", duration=2)
unscrew_front_right_tyre = ps.FixedDurationTask(
    name="UnScrewFrontRightTyre", duration=2
)
unscrew_rear_left_tyre = ps.FixedDurationTask(name="UnScrewRearLeftTyre", duration=2)
unscrew_rear_right_tyre = ps.FixedDurationTask(name="UnScrewRearRightTyre", duration=2)

gunner_unscrew_front_left_tyre = ps.SelectWorkers(
    list_of_workers=gunners, nb_workers_to_select=1
)
unscrew_front_left_tyre.add_required_resource(gunner_unscrew_front_left_tyre)

gunner_unscrew_front_right_tyre = ps.SelectWorkers(
    list_of_workers=gunners, nb_workers_to_select=1
)
unscrew_front_right_tyre.add_required_resource(gunner_unscrew_front_right_tyre)

gunner_unscrew_rear_left_tyre = ps.SelectWorkers(
    list_of_workers=gunners, nb_workers_to_select=1
)
unscrew_rear_left_tyre.add_required_resource(gunner_unscrew_rear_left_tyre)

gunner_unscrew_rear_right_tyre = ps.SelectWorkers(
    list_of_workers=gunners, nb_workers_to_select=1
)
unscrew_rear_right_tyre.add_required_resource(gunner_unscrew_rear_right_tyre)

# screw tasks and gunners
screw_front_left_tyre = ps.FixedDurationTask(name="ScrewFrontLeftTyre", duration=2)
screw_front_right_tyre = ps.FixedDurationTask(name="ScrewFrontRightTyre", duration=2)
screw_rear_left_tyre = ps.FixedDurationTask(name="ScrewRearLeftTyre", duration=2)
screw_rear_right_tyre = ps.FixedDurationTask(name="ScrewRearRightTyre", duration=2)

gunner_screw_front_left_tyre = ps.SelectWorkers(list_of_workers=gunners)
screw_front_left_tyre.add_required_resource(gunner_screw_front_left_tyre)

gunner_screw_front_right_tyre = ps.SelectWorkers(list_of_workers=gunners)
screw_front_right_tyre.add_required_resource(gunner_screw_front_right_tyre)

gunner_screw_rear_left_tyre = ps.SelectWorkers(list_of_workers=gunners)
screw_rear_left_tyre.add_required_resource(gunner_screw_rear_left_tyre)

gunner_screw_rear_right_tyre = ps.SelectWorkers(list_of_workers=gunners)
screw_rear_right_tyre.add_required_resource(gunner_screw_rear_right_tyre)

# %%
# tires OFF and handlers
front_left_tyre_off = ps.FixedDurationTask(name="FrontLeftTyreOff", duration=2)
front_right_tyre_off = ps.FixedDurationTask(name="FrontRightTyreOff", duration=2)
rear_left_tyre_off = ps.FixedDurationTask(name="RearLeftTyreOff", duration=2)
rear_right_tyre_off = ps.FixedDurationTask(name="RearRightTyreOff", duration=2)

for tyre_off_task in [
    front_left_tyre_off,
    front_right_tyre_off,
    rear_left_tyre_off,
    rear_right_tyre_off,
]:
    tyre_off_task.add_required_resource(ps.SelectWorkers(list_of_workers=tyre_handlers))

# tires ON and handlers, same as above
front_left_tyre_on = ps.FixedDurationTask(name="FrontLeftTyreOn", duration=2)
front_right_tyre_on = ps.FixedDurationTask(name="FrontRightTyreOn", duration=2)
rear_left_tyre_on = ps.FixedDurationTask(name="RearLeftTyreOn", duration=2)
rear_right_tyre_on = ps.FixedDurationTask(name="RearRightTyreOn", duration=2)

for tyre_on_task in [
    front_left_tyre_on,
    front_right_tyre_on,
    rear_left_tyre_on,
    rear_right_tyre_on,
]:
    tyre_on_task.add_required_resource(ps.SelectWorkers(list_of_workers=tyre_handlers))

# %% [markdown]
# **Stabilizers** start their job as soon as the car is stopped until the end of the whole activity.

# %%
stabilize_left = ps.VariableDurationTask(name="StabilizeLeft")
stabilize_right = ps.VariableDurationTask(name="StabilizeRight")

stabilize_left.add_required_resource(stabilizers[0])
stabilize_right.add_required_resource(stabilizers[1])

ps.TaskStartAt(task=stabilize_left, value=0)
ps.TaskStartAt(task=stabilize_right, value=0)

ps.TaskEndAt(task=stabilize_left, value=change_tires_problem._horizon)
ps.TaskEndAt(task=stabilize_right, value=change_tires_problem._horizon)

# %% [markdown]
# ### Task precedences

# %%
# front left tyre operations
fr_left = [
    unscrew_front_left_tyre,
    front_left_tyre_off,
    front_left_tyre_on,
    screw_front_left_tyre,
]
for i in range(len(fr_left) - 1):
    ps.TaskPrecedence(task_before=fr_left[i], task_after=fr_left[i + 1])
# front right tyre operations
fr_right = [
    unscrew_front_right_tyre,
    front_right_tyre_off,
    front_right_tyre_on,
    screw_front_right_tyre,
]
for i in range(len(fr_right) - 1):
    ps.TaskPrecedence(task_before=fr_right[i], task_after=fr_right[i + 1])
# rear left tyre operations
re_left = [
    unscrew_rear_left_tyre,
    rear_left_tyre_off,
    rear_left_tyre_on,
    screw_rear_left_tyre,
]
for i in range(len(re_left) - 1):
    ps.TaskPrecedence(task_before=re_left[i], task_after=re_left[i + 1])
# front left tyre operations
re_right = [
    unscrew_rear_right_tyre,
    rear_right_tyre_off,
    rear_right_tyre_on,
    screw_rear_right_tyre,
]
for i in range(len(re_right) - 1):
    ps.TaskPrecedence(task_before=re_right[i], task_after=re_right[i + 1])

# all un screw operations must start after the car is lift by both front and rear jacks
for unscrew_tasks in [
    unscrew_front_left_tyre,
    unscrew_front_right_tyre,
    unscrew_rear_left_tyre,
    unscrew_rear_right_tyre,
]:
    ps.TaskPrecedence(task_before=lift_rear_up, task_after=unscrew_tasks)
    ps.TaskPrecedence(task_before=lift_front_up, task_after=unscrew_tasks)

# lift down operations must occur after each screw task is completed
for screw_task in [
    screw_front_left_tyre,
    screw_front_right_tyre,
    screw_rear_left_tyre,
    screw_rear_right_tyre,
]:
    ps.TaskPrecedence(task_before=screw_task, task_after=lift_rear_down)
    ps.TaskPrecedence(task_before=screw_task, task_after=lift_front_down)

# %% [markdown]
# ### First solution, plot the schedule

# %%
solver = ps.SchedulingSolver(problem=change_tires_problem)
solution_1 = solver.solve()
ps.render_gantt_matplotlib(solution_1, fig_size=(10, 5), render_mode="Resource")

# %% [markdown]
# ### Second solution: add a makespan objective
# Obviously, the former solution is not the *best* solution, not sure Ferrari will win this race ! The whole "change tires" activity must be as short as possible, so let's add a *makespan* objective, i.e. a constraint that minimizes the schedule horizon.

# %%
# add makespan objective
change_tires_problem.add_objective_makespan()

solver_2 = ps.SchedulingSolver(problem=change_tires_problem)
solution_2 = solver_2.solve()
ps.render_gantt_matplotlib(solution_2, fig_size=(9, 5), render_mode="Task")

# %% [markdown]
# ### Third solution: constraint workers
# This is not the best possible solution. Indeed, we can notice that the Gunner2 unscrews the RearRightTyre and screw the RearLeft tyre. We cannot imagine that a solution where gunners turn around the car is acceptable. There are two solutions to fix the schedule:
# -   let the gunner be able to turn around the car, and add a "Move" task with a duration that represent the time necessary to move from one tyre to the other,
# -   constraint the worker to screw the same tyre he unscrewed. Let's go this way

# %%
ps.SameWorkers(
    select_workers_1=gunner_unscrew_front_left_tyre,
    select_workers_2=gunner_screw_front_left_tyre,
)
ps.SameWorkers(
    select_workers_1=gunner_unscrew_front_right_tyre,
    select_workers_2=gunner_screw_front_right_tyre,
)
ps.SameWorkers(
    select_workers_1=gunner_unscrew_rear_left_tyre,
    select_workers_2=gunner_screw_rear_left_tyre,
)
ps.SameWorkers(
    select_workers_1=gunner_unscrew_rear_right_tyre,
    select_workers_2=gunner_screw_rear_right_tyre,
)

solver_3 = ps.SchedulingSolver(problem=change_tires_problem)
solution_3 = solver_3.solve()
ps.render_gantt_matplotlib(solution_3, fig_size=(9, 5), render_mode="Task")
# Out:
# 	Found value: -1854 elapsed time:4.982s
# 	Checking better value < -1854
# 	Found value: -1856 elapsed time:4.988s
# 	Checking better value < -1856
# 	Found value: -1858 elapsed time:4.993s
# 	Checking better value < -1858
# 	Found value: -1860 elapsed time:4.998s
# 	Checking better value < -1860
# 	Found value: -1862 elapsed time:5.003s
# 	Checking better value < -1862
# 	Found value: -1864 elapsed time:5.008s
# 	Checking better value < -1864
# 	Found value: -1866 elapsed time:5.013s
# 	Checking better value < -1866
# 	Found value: -1868 elapsed time:5.018s
# 	Checking better value < -1868
# 	Found value: -1870 elapsed time:5.022s
# 	Checking better value < -1870
# 	Found value: -1872 elapsed time:5.027s
# 	Checking better value < -1872
# 	Found value: -1874 elapsed time:5.032s
# 	Checking better value < -1874
# 	Found value: -1876 elapsed time:5.037s
# 	Checking better value < -1876
# 	Found value: -1878 elapsed time:5.043s
# 	Checking better value < -1878
# 	Found value: -1880 elapsed time:5.049s
# 	Checking better value < -1880
# 	Found value: -1882 elapsed time:5.055s
# 	Checking better value < -1882
# 	Found value: -1884 elapsed time:5.062s
# 	Checking better value < -1884
# 	Found value: -1886 elapsed time:5.067s
# 	Checking better value < -1886
# 	Found value: -1888 elapsed time:5.072s
# 	Checking better value < -1888
# 	Found value: -1890 elapsed time:5.077s
# 	Checking better value < -1890
# 	Found value: -1892 elapsed time:5.082s
# 	Checking better value < -1892
# 	Found value: -1894 elapsed time:5.088s
# 	Checking better value < -1894
# 	Found value: -1896 elapsed time:5.094s
# 	Checking better value < -1896
# 	Found value: -1898 elapsed time:5.099s
# 	Checking better value < -1898
# 	Found value: -1900 elapsed time:5.104s
# 	Checking better value < -1900
# 	Found value: -1902 elapsed time:5.109s
# 	Checking better value < -1902
# 	Found value: -1904 elapsed time:5.115s
# 	Checking better value < -1904
# 	Found value: -1906 elapsed time:5.121s
# 	Checking better value < -1906
# 	Found value: -1908 elapsed time:5.126s
# 	Checking better value < -1908
# 	Found value: -1910 elapsed time:5.131s
# 	Checking better value < -1910
# 	Found value: -1912 elapsed time:5.135s
# 	Checking better value < -1912
# 	Found value: -1914 elapsed time:5.140s
# 	Checking better value < -1914
# 	Found value: -1916 elapsed time:5.145s
# 	Checking better value < -1916
# 	Found value: -1918 elapsed time:5.150s
# 	Checking better value < -1918
# 	Found value: -1920 elapsed time:5.154s
# 	Checking better value < -1920
# 	Found value: -1922 elapsed time:5.159s
# 	Checking better value < -1922
# 	Found value: -1924 elapsed time:5.164s
# 	Checking better value < -1924
# 	Found value: -1926 elapsed time:5.169s
# 	Checking better value < -1926
# 	Found value: -1928 elapsed time:5.173s
# 	Checking better value < -1928
# 	Found value: -1930 elapsed time:5.179s
# 	Checking better value < -1930
# 	Found value: -1932 elapsed time:5.183s
# 	Checking better value < -1932
# 	Found value: -1934 elapsed time:5.188s
# 	Checking better value < -1934
# 	Found value: -1936 elapsed time:5.193s
# 	Checking better value < -1936
# 	Found value: -1938 elapsed time:5.198s
# 	Checking better value < -1938
# 	Found value: -1940 elapsed time:5.203s
# 	Checking better value < -1940
# 	Found value: -1942 elapsed time:5.207s
# 	Checking better value < -1942
# 	Found value: -1944 elapsed time:5.212s
# 	Checking better value < -1944
# 	Found value: -1946 elapsed time:5.217s
# 	Checking better value < -1946
# 	Found value: -1948 elapsed time:5.222s
# 	Checking better value < -1948
# 	Found value: -1950 elapsed time:5.226s
# 	Checking better value < -1950
# 	Found value: -1952 elapsed time:5.231s
# 	Checking better value < -1952
# 	Found value: -1954 elapsed time:5.236s
# 	Checking better value < -1954
# 	Found value: -1956 elapsed time:5.242s
# 	Checking better value < -1956
# 	Found value: -1958 elapsed time:5.248s
# 	Checking better value < -1958
# 	Found value: -1960 elapsed time:5.252s
# 	Checking better value < -1960
# 	Found value: -1962 elapsed time:5.258s
# 	Checking better value < -1962
# 	Found value: -1964 elapsed time:5.263s
# 	Checking better value < -1964
# 	Found value: -1966 elapsed time:5.268s
# 	Checking better value < -1966
# 	Found value: -1968 elapsed time:5.273s
# 	Checking better value < -1968
# 	Found value: -1970 elapsed time:5.278s
# 	Checking better value < -1970
# 	Found value: -1972 elapsed time:5.282s
# 	Checking better value < -1972
# 	Found value: -1974 elapsed time:5.287s
# 	Checking better value < -1974
# 	Found value: -1976 elapsed time:5.292s
# 	Checking better value < -1976
# 	Found value: -1978 elapsed time:5.297s
# 	Checking better value < -1978
# 	Found value: -1980 elapsed time:5.301s
# 	Checking better value < -1980
# 	Found value: -1982 elapsed time:5.306s
# 	Checking better value < -1982
# 	Found value: -1984 elapsed time:5.311s
# 	Checking better value < -1984
# 	Found value: -1986 elapsed time:5.316s
# 	Checking better value < -1986
# 	Found value: -1988 elapsed time:5.321s
# 	Checking better value < -1988
# 	Found value: -1990 elapsed time:5.327s
# 	Checking better value < -1990
# 	Found value: -1992 elapsed time:5.332s
# 	Checking better value < -1992
# 	Found value: -1994 elapsed time:5.337s
# 	Checking better value < -1994
# 	Found value: -1996 elapsed time:5.343s
# 	Checking better value < -1996
# 	Found value: -1998 elapsed time:5.348s
# 	Checking better value < -1998
# 	Found value: -2000 elapsed time:5.353s
# 	Checking better value < -2000
# 	Found value: -2002 elapsed time:5.358s
# 	Checking better value < -2002
# 	Found value: -2004 elapsed time:5.364s
# 	Checking better value < -2004
# 	Found value: -2006 elapsed time:5.369s
# 	Checking better value < -2006
# 	Found value: -2008 elapsed time:5.376s
# 	Checking better value < -2008
# 	Found value: -2010 elapsed time:5.382s
# 	Checking better value < -2010
# 	Found value: -2012 elapsed time:5.387s
# 	Checking better value < -2012
# 	Found value: -2014 elapsed time:5.393s
# 	Checking better value < -2014
# 	Found value: -2016 elapsed time:5.398s
# 	Checking better value < -2016
# 	Found value: -2018 elapsed time:5.403s
# 	Checking better value < -2018
# 	Found value: -2020 elapsed time:5.409s
# 	Checking better value < -2020
# 	Found value: -2022 elapsed time:5.414s
# 	Checking better value < -2022
# 	Found value: -2024 elapsed time:5.419s
# 	Checking better value < -2024
# 	Found value: -2026 elapsed time:5.424s
# 	Checking better value < -2026
# 	Found value: -2028 elapsed time:5.429s
# 	Checking better value < -2028
# 	Found value: -2030 elapsed time:5.434s
# 	Checking better value < -2030
# 	Found value: -2032 elapsed time:5.440s
# 	Checking better value < -2032
# 	Found value: -2034 elapsed time:5.445s
# 	Checking better value < -2034
# 	Found value: -2036 elapsed time:5.450s
# 	Checking better value < -2036
# 	Found value: -2038 elapsed time:5.455s
# 	Checking better value < -2038
# 	Found value: -2040 elapsed time:5.460s
# 	Checking better value < -2040
# 	Found value: -2042 elapsed time:5.465s
# 	Checking better value < -2042
# 	Found value: -2044 elapsed time:5.470s
# 	Checking better value < -2044
# 	Found value: -2046 elapsed time:5.475s
# 	Checking better value < -2046
# 	Found value: -2048 elapsed time:5.481s
# 	Checking better value < -2048
# 	Found value: -2050 elapsed time:5.486s
# 	Checking better value < -2050
# 	Found value: -2052 elapsed time:5.491s
# 	Checking better value < -2052
# 	Found value: -2054 elapsed time:5.497s
# 	Checking better value < -2054
# 	Found value: -2056 elapsed time:5.502s
# 	Checking better value < -2056
# 	Found value: -2058 elapsed time:5.507s
# 	Checking better value < -2058
# 	Found value: -2060 elapsed time:5.512s
# 	Checking better value < -2060
# 	Found value: -2062 elapsed time:5.517s
# 	Checking better value < -2062
# 	Found value: -2064 elapsed time:5.522s
# 	Checking better value < -2064
# 	Found value: -2066 elapsed time:5.527s
# 	Checking better value < -2066
# 	Found value: -2068 elapsed time:5.532s
# 	Checking better value < -2068
# 	Found value: -2070 elapsed time:5.537s
# 	Checking better value < -2070
# 	Found value: -2072 elapsed time:5.542s
# 	Checking better value < -2072
# 	Found value: -2074 elapsed time:5.548s
# 	Checking better value < -2074
# 	Found value: -2076 elapsed time:5.553s
# 	Checking better value < -2076
# 	Found value: -2078 elapsed time:5.558s
# 	Checking better value < -2078
# 	Found value: -2080 elapsed time:5.563s
# 	Checking better value < -2080
# 	Found value: -2082 elapsed time:5.568s
# 	Checking better value < -2082
# 	Found value: -2084 elapsed time:5.574s
# 	Checking better value < -2084
# 	Found value: -2086 elapsed time:5.579s
# 	Checking better value < -2086
# 	Found value: -2088 elapsed time:5.584s
# 	Checking better value < -2088
# 	Found value: -2090 elapsed time:5.589s
# 	Checking better value < -2090
# 	Found value: -2092 elapsed time:5.595s
# 	Checking better value < -2092
# 	Found value: -2094 elapsed time:5.600s
# 	Checking better value < -2094
# 	Found value: -2096 elapsed time:5.605s
# 	Checking better value < -2096
# 	Found value: -2098 elapsed time:5.610s
# 	Checking better value < -2098
# 	Found value: -2100 elapsed time:5.615s
# 	Checking better value < -2100
# 	Found value: -2102 elapsed time:5.621s
# 	Checking better value < -2102
# 	Found value: -2104 elapsed time:5.626s
# 	Checking better value < -2104
# 	Found value: -2106 elapsed time:5.631s
# 	Checking better value < -2106
# 	Found value: -2108 elapsed time:5.636s
# 	Checking better value < -2108
# 	Found value: -2110 elapsed time:5.641s
# 	Checking better value < -2110
# 	Found value: -2112 elapsed time:5.646s
# 	Checking better value < -2112
# 	Found value: -2114 elapsed time:5.652s
# 	Checking better value < -2114
# 	Found value: -2116 elapsed time:5.657s
# 	Checking better value < -2116
# 	Found value: -2118 elapsed time:5.662s
# 	Checking better value < -2118
# 	Found value: -2120 elapsed time:5.667s
# 	Checking better value < -2120
# 	Found value: -2122 elapsed time:5.672s
# 	Checking better value < -2122
# 	Found value: -2124 elapsed time:5.677s
# 	Checking better value < -2124
# 	Found value: -2126 elapsed time:5.682s
# 	Checking better value < -2126
# 	Found value: -2128 elapsed time:5.687s
# 	Checking better value < -2128
# 	Found value: -2130 elapsed time:5.692s
# 	Checking better value < -2130
# 	Found value: -2132 elapsed time:5.697s
# 	Checking better value < -2132
# 	Found value: -2134 elapsed time:5.702s
# 	Checking better value < -2134
# 	Found value: -2136 elapsed time:5.707s
# 	Checking better value < -2136
# 	Found value: -2138 elapsed time:5.713s
# 	Checking better value < -2138
# 	Found value: -2140 elapsed time:5.718s
# 	Checking better value < -2140
# 	Found value: -2142 elapsed time:5.723s
# 	Checking better value < -2142
# 	Found value: -2144 elapsed time:5.729s
# 	Checking better value < -2144
# 	Found value: -2146 elapsed time:5.735s
# 	Checking better value < -2146
# 	Found value: -2148 elapsed time:5.740s
# 	Checking better value < -2148
# 	Found value: -2150 elapsed time:5.746s
# 	Checking better value < -2150

# %% [markdown]
# This is much better !
