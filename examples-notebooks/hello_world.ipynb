# %%
# %matplotlib widget
import processscheduler as ps

# %%
# a simple problem, without horizon (solver will find it)
pb = ps.SchedulingProblem(name="HelloWorld")

# add two tasks
task_hello = ps.FixedDurationTask(name="Hello", duration=2)
task_world = ps.FixedDurationTask(name="World", duration=2)

# precedence constraint: task_wolrd must be scheduled
# after task_hello
ps.TaskPrecedence(task_before=task_hello, task_after=task_world, offset=0)
# Out:
# TaskPrecedence_12138395(<class 'processscheduler.task_constraint.TaskPrecedence'>)
# 1 assertion(s):
# Hello_end <= World_start

# %%
# solve
solver = ps.SchedulingSolver(problem=pb)
sol = solver.solve()
# Out:
# Solver type:
# ===========
# 	-> Standard SAT/SMT solver
# Total computation time:
# =====================
# 	HelloWorld satisfiability checked in 0.01s

# %%
# displays solution, ascii or matplotlib gantt diagram
print(sol.to_json())
# Out:
# {
#     "name": "SchedulingSolution_31281419",
#     "type": "SchedulingSolution",
#     "problem": {
#         "name": "HelloWorld",
#         "type": "SchedulingProblem",
#         "horizon": null,
#         "delta_time": null,
#         "start_time": null,
#         "end_time": null,
#         "tasks": {
#             "Hello": {
#                 "name": "Hello",
#                 "type": "FixedDurationTask",
#                 "optional": false,
#                 "work_amount": 0,
#                 "release_date": null,
#                 "due_date": null,
#                 "due_date_is_deadline": true,
#                 "priority": 1,
#                 "duration": 2
#             },
#             "World": {
#                 "name": "World",
#                 "type": "FixedDurationTask",
#                 "optional": false,
#                 "work_amount": 0,
#                 "release_date": null,
#                 "due_date": null,
#                 "due_date_is_deadline": true,
#                 "priority": 1,
#                 "duration": 2
#             }
#         },
#         "workers": {},
#         "select_workers": {},
#         "cumulative_workers": {},
#         "constraints": {
#             "TaskPrecedence_12138395": {
#                 "name": "TaskPrecedence_12138395",
#                 "type": "TaskPrecedence",
#                 "optional": false,
#                 "task_before": {
#                     "name": "Hello",
#                     "type": "FixedDurationTask",
#                     "optional": false,
#                     "work_amount": 0,
#                     "release_date": null,
#                     "due_date": null,
#                     "due_date_is_deadline": true,
#                     "priority": 1,
#                     "duration": 2
#                 },
#                 "task_after": {
#                     "name": "World",
#                     "type": "FixedDurationTask",
#                     "optional": false,
#                     "work_amount": 0,
#                     "release_date": null,
#                     "due_date": null,
#                     "due_date_is_deadline": true,
#                     "priority": 1,
#                     "duration": 2
#                 },
#                 "offset": 0,
#                 "kind": "lax"
#             }
#         },
#         "indicators": {},
#         "objectives": {},
#         "buffers": []
#     },
#     "horizon": 4,
#     "tasks": {
#         "Hello": {
#             "name": "Hello",
#             "type": "FixedDurationTask",
#             "start": 0,
#             "end": 2,
#             "duration": 2,
#             "release_date": null,
#             "due_date": null,
#             "due_date_is_deadline": true,
#             "start_time": null,
#             "end_time": null,
#             "duration_time": null,
#             "optional": false,
#             "scheduled": true,
#             "work_amount": 0,
#             "priority": 1,
#             "assigned_resources": []
#         },
#         "World": {
#             "name": "World",
#             "type": "FixedDurationTask",
#             "start": 2,
#             "end": 4,
#             "duration": 2,
#             "release_date": null,
#             "due_date": null,
#             "due_date_is_deadline": true,
#             "start_time": null,
#             "end_time": null,
#             "duration_time": null,
#             "optional": false,
#             "scheduled": true,
#             "work_amount": 0,
#             "priority": 1,
#             "assigned_resources": []
#         }
#     },
#     "resources": {},
#     "buffers": {},
#     "indicators": {}
# }

# %%
ps.render_gantt_matplotlib(sol, render_mode="Tasks")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
